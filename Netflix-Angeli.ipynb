# %%
#Python File for ETL Project

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#Extract CSV's into DataFrames

# %%
# File Legend:

# CSV_1: Netflix Titles
# CSV_2: Metascore Data

# %%
#Netflix Titles

CSV_1 = "Resources/netflix_titles.csv"
netflix_df = pd.read_csv(CSV_1)
netflix_df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
#List total columns & identify columns for revised dataframe

for col in netflix_df.columns: 
    print(col)
# Out:
# show_id
# type
# title
# director
# cast
# country
# date_added
# release_year
# rating
# duration
# listed_in
# description

# %%
#Columns in final Netflix Table
# type (want to filter just to movies)
# title
# director
# cast (should separate each actor)
# county
# date added
# release year
# rating 
# listed in (genres)
# description

# %%
#Revised Netflix DataFrame

revised_netflix_df = netflix_df[["type","title","director","country","release_year","listed_in","description"]]
revised_netflix_df.head()

#Columns in final Netflix Table
# type (want to filter just to movies)
# title
# director
# county
# date added
# release year
# rating 
# listed in (genres)
# description
# Out:
#       type  title           director        country  release_year  \
# 0  TV Show     3%                NaN         Brazil          2020
# 1    Movie   7:19  Jorge Michel Grau         Mexico          2016
# 2    Movie  23:59       Gilbert Chan      Singapore          2011
# 3    Movie      9        Shane Acker  United States          2009
# 4    Movie     21     Robert Luketic  United States          2008
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
# filter out tv type
drop_netflix_df = revised_netflix_df[revised_netflix_df.type != 'TV Show']
drop_netflix_df.head()
# Out:
#     type  title           director        country  release_year  \
# 1  Movie   7:19  Jorge Michel Grau         Mexico          2016
# 2  Movie  23:59       Gilbert Chan      Singapore          2011
# 3  Movie      9        Shane Acker  United States          2009
# 4  Movie     21     Robert Luketic  United States          2008
# 6  Movie    122    Yasir Al Yasiri          Egypt          2019
#
#                                            listed_in  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
# 6                Horror Movies, International Movies
#
#                                          description
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...
# 6  After an awful accident, a couple admitted to ...

# %%
# Rename columns
renamed_netflix_df = drop_netflix_df.rename(columns={"title":"movie_title","country":"produced_in","listed_in": "netflix_genre"})
renamed_netflix_df.head()
# Out:
#     type movie_title           director    produced_in  release_year  \
# 1  Movie        7:19  Jorge Michel Grau         Mexico          2016
# 2  Movie       23:59       Gilbert Chan      Singapore          2011
# 3  Movie           9        Shane Acker  United States          2009
# 4  Movie          21     Robert Luketic  United States          2008
# 6  Movie         122    Yasir Al Yasiri          Egypt          2019
#
#                                        netflix_genre  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
# 6                Horror Movies, International Movies
#
#                                          description
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...
# 6  After an awful accident, a couple admitted to ...

# %%
# Remove Type Column
movie_netflix_df = renamed_netflix_df.drop('type', axis=1)
movie_netflix_df.head(50)
# Out:
#                                  movie_title  \
# 1                                       7:19
# 2                                      23:59
# 3                                          9
# 4                                         21
# 6                                        122
# 7                                        187
# 8                                        706
# 9                                       1920
# 10                                      1922
# 13                                     2,215
# 14                                      3022
# 15                                    Oct-01
# 17                                    22-Jul
# 18                                    15-Aug
# 19                                       '89
# 20                      ​​Kuch Bheege Alfaaz
# 21                              ​Goli Soda 2
# 22                        ​Maj Rati ​​Keteki
# 23                               ​Mayurakshi
# 25                                  (T)ERROR
# 27                                    #Alive
# 28             #AnneFrank - Parallel Stories
# 30                          #cats_the_mewvie
# 31                         #FriendButMarried
# 32                       #FriendButMarried 2
# 33                              #realityhigh
# 34                                     #Roxy
# 35                                 #Rucker50
# 36                                   #Selfie
# 37                                #Selfie 69
# 39                            ¡Ay, mi madre!
# 40                               Çarsi Pazar
# 41                                Ég man þig
# 42               Çok Filim Hareketler Bunlar
# 43                                   Òlòtūré
# 44                                  Æon Flux
# 46                          1 Chance 2 Dance
# 47                             1 Mile to You
# 48                       10 Days in Sun City
# 49                            10 jours en or
# 50                               10,000 B.C.
# 52                      100 Days Of Solitude
# 54                                100 Meters
# 55       100 Things to do Before High School
# 56  100 Years: One Woman's Fight for Justice
# 57                                100% Halal
# 59                           1000 Rupee Note
# 60                              12 ROUND GUN
# 62                                13 Cameras
# 65                                   13 Sins
#
#                                   director                     produced_in  \
# 1                        Jorge Michel Grau                          Mexico
# 2                             Gilbert Chan                       Singapore
# 3                              Shane Acker                   United States
# 4                           Robert Luketic                   United States
# 6                          Yasir Al Yasiri                           Egypt
# 7                           Kevin Reynolds                   United States
# 8                            Shravan Kumar                           India
# 9                             Vikram Bhatt                           India
# 10                            Zak Hilditch                   United States
# 13                     Nottapon Boonprakob                        Thailand
# 14                              John Suits                   United States
# 15                          Kunle Afolayan                         Nigeria
# 17                         Paul Greengrass  Norway, Iceland, United States
# 18                      Swapnaneel Jayakar                           India
# 19                                     NaN                  United Kingdom
# 20                                    Onir                           India
# 21                            Vijay Milton                           India
# 22                       Santwana Bardoloi                           India
# 23                             Atanu Ghosh                           India
# 25  Lyric R. Cabral, David Felix Sutcliffe                   United States
# 27                                  Cho Il                     South Korea
# 28             Sabina Fedeli, Anna Migotto                           Italy
# 30                        Michael Margolis                          Canada
# 31                           Rako Prijanto                       Indonesia
# 32                           Rako Prijanto                       Indonesia
# 33                        Fernando Lebrija                   United States
# 34                         Michael Kennedy                          Canada
# 35                   Robert McCullough Jr.                   United States
# 36                          Cristina Jacob                         Romania
# 37                          Cristina Jacob                         Romania
# 39                             Frank Ariza                           Spain
# 40                         Muharrem Gülmez                          Turkey
# 41                     Óskar Thór Axelsson                         Iceland
# 42                            Ozan Açıktan                          Turkey
# 43                           Kenneth Gyang                         Nigeria
# 44                            Karyn Kusama                   United States
# 46                              Adam Deyoe                   United States
# 47                             Leif Tilden                   United States
# 48                               Adze Ugah           South Africa, Nigeria
# 49                       Nicolas Brossette                          France
# 50                         Roland Emmerich     United States, South Africa
# 52                                     NaN                           Spain
# 54                          Marcel Barrena                 Portugal, Spain
# 55                                     NaN                   United States
# 56                           Melinda Janko                   United States
# 57                           Jastis Arimba                       Indonesia
# 59                          Shrihari Sathe                           India
# 60                               Sam Upton                   United States
# 62                          Victor Zarcoff                   United States
# 65                            Daniel Stamm                   United States
#
#     release_year                                      netflix_genre  \
# 1           2016                       Dramas, International Movies
# 2           2011                Horror Movies, International Movies
# 3           2009  Action & Adventure, Independent Movies, Sci-Fi...
# 4           2008                                             Dramas
# 6           2019                Horror Movies, International Movies
# 7           1997                                             Dramas
# 8           2019                Horror Movies, International Movies
# 9           2008     Horror Movies, International Movies, Thrillers
# 10          2017                                  Dramas, Thrillers
# 13          2018  Documentaries, International Movies, Sports Mo...
# 14          2019    Independent Movies, Sci-Fi & Fantasy, Thrillers
# 15          2014            Dramas, International Movies, Thrillers
# 17          2018                                  Dramas, Thrillers
# 18          2019               Comedies, Dramas, Independent Movies
# 19          2017                                      Sports Movies
# 20          2018   Dramas, Independent Movies, International Movies
# 21          2018   Action & Adventure, Dramas, International Movies
# 22          2017                       Dramas, International Movies
# 23          2017                       Dramas, International Movies
# 25          2015                                      Documentaries
# 27          2020     Horror Movies, International Movies, Thrillers
# 28          2019                Documentaries, International Movies
# 30          2020                Documentaries, International Movies
# 31          2018      Dramas, International Movies, Romantic Movies
# 32          2020      Dramas, International Movies, Romantic Movies
# 33          2017                                           Comedies
# 34          2018                          Comedies, Romantic Movies
# 35          2016                       Documentaries, Sports Movies
# 36          2014             Comedies, Dramas, International Movies
# 37          2016             Comedies, Dramas, International Movies
# 39          2019                     Comedies, International Movies
# 40          2015                     Comedies, International Movies
# 41          2017                Horror Movies, International Movies
# 42          2010                     Comedies, International Movies
# 43          2020                       Dramas, International Movies
# 44          2005               Action & Adventure, Sci-Fi & Fantasy
# 46          2014                            Dramas, Romantic Movies
# 47          2017             Dramas, Romantic Movies, Sports Movies
# 48          2017    Comedies, International Movies, Romantic Movies
# 49          2012             Comedies, Dramas, International Movies
# 50          2008                                 Action & Adventure
# 52          2018                Documentaries, International Movies
# 54          2016        Dramas, International Movies, Sports Movies
# 55          2014                                             Movies
# 56          2016                                      Documentaries
# 57          2020                       Dramas, International Movies
# 59          2014                       Dramas, International Movies
# 60          2017          Dramas, Independent Movies, Sports Movies
# 62          2015       Horror Movies, Independent Movies, Thrillers
# 65          2014                           Horror Movies, Thrillers
#
#                                           description
# 1   After a devastating earthquake hits Mexico Cit...
# 2   When an army recruit is found dead, his fellow...
# 3   In a postapocalyptic world, rag-doll robots hi...
# 4   A brilliant group of students become card-coun...
# 6   After an awful accident, a couple admitted to ...
# 7   After one of his high school students attacks ...
# 8   When a doctor goes missing, his psychiatrist w...
# 9   An architect and his wife move into a castle t...
# 10  A farmer pens a confession admitting to his wi...
# 13  This intimate documentary follows rock star Ar...
# 14  Stranded when the Earth is suddenly destroyed ...
# 15  Against the backdrop of Nigeria's looming inde...
# 17  After devastating terror attacks in Norway, a ...
# 18  On India's Independence Day, a zany mishap in ...
# 19  Mixing old footage with interviews, this is th...
# 20  After accidentally connecting over the Interne...
# 21  A taxi driver, a gangster and an athlete strug...
# 22  A successful writer returns to the town that l...
# 23  When a middle-aged divorcee returns to Kolkata...
# 25  This real-life look at FBI counterterrorism op...
# 27  As a grisly virus rampages a city, a lone man ...
# 28  Through her diary, Anne Frank's story is retol...
# 30  This pawesome documentary explores how our fel...
# 31  Pining for his high school crush for years, a ...
# 32  As Ayu and Ditto finally transition from best ...
# 33  When nerdy high schooler Dani finally attracts...
# 34  A teenage hacker with a huge nose helps a cool...
# 35  This documentary celebrates the 50th anniversa...
# 36  Two days before their final exams, three teen ...
# 37  After a painful breakup, a trio of party-lovin...
# 39  When her estranged mother suddenly dies, a wom...
# 40  The slacker owner of a public bath house ralli...
# 41  Young urbanites renovating a rundown house, an...
# 42  Vignettes of the summer holidays follow vacati...
# 43  In Lagos, a journalist goes undercover as a pr...
# 44  Aiming to hasten an uprising, the leader of an...
# 46  When an aspiring dancer is uprooted during her...
# 47  After escaping the bus accident that killed hi...
# 48  After his girlfriend wins the Miss Nigeria pag...
# 49  When a carefree bachelor is unexpectedly left ...
# 50  Fierce mammoth hunter D'Leh sets out on an imp...
# 52  Spanish photographer José Díaz spends 100 days...
# 54  A man who is diagnosed with multiple sclerosis...
# 55  Led by seventh-grader C.J., three students who...
# 56  This documentary chronicles Elouise Cobell's l...
# 57  After high school, a young woman marries the m...
# 59  After randomly receiving a handsome political ...
# 60  Dealing with personal demons and the death of ...
# 62  Young parents-to-be Claire and Ryan move into ...
# 65  A man agrees to appear on a game show with a $...

# %%
# split produced_in
# Define 1st value in listed_in column as main country the movie was produced in
produced_df = movie_netflix_df

# split genre column
split_produced_df = produced_df['produced_in'].str.split(',', 1, expand=True)

# Rename columns
renamed_produced_df = split_produced_df.rename(columns={0:"primary_country",1:"other_countries"})
renamed_produced_df.head()

# drop column
country_df = renamed_produced_df.drop('other_countries', axis=1)
country_df.head()
# Out:
#   primary_country
# 1          Mexico
# 2       Singapore
# 3   United States
# 4   United States
# 6           Egypt

# %%
# Get Unique Values in 
country_list = country_df['primary_country'].unique()
country_list
# Out:
# array(['Mexico', 'Singapore', 'United States', 'Egypt', 'India',
#        'Thailand', 'Nigeria', 'Norway', 'United Kingdom', 'South Korea',
#        'Italy', 'Canada', 'Indonesia', 'Romania', 'Spain', 'Turkey',
#        'Iceland', 'South Africa', 'France', 'Portugal', nan, 'Hong Kong',
#        'Argentina', 'Germany', 'Denmark', 'Poland', 'Japan', 'Kenya',
#        'New Zealand', 'Pakistan', 'Australia', 'China', 'Taiwan',
#        'Netherlands', 'Philippines', 'United Arab Emirates', 'Brazil',
#        'Iran', 'Israel', 'Uruguay', 'Bulgaria', 'Colombia',
#        'Soviet Union', 'Sweden', 'Malaysia', 'Ireland', 'Serbia', 'Peru',
#        'Chile', 'Ghana', 'Saudi Arabia', 'Namibia', 'Lebanon', 'Belgium',
#        'Vietnam', 'Russia', 'Kuwait', 'Czech Republic', 'Zimbabwe',
#        'Hungary', 'Finland', 'Venezuela', 'Cambodia', 'West Germany',
#        'Slovenia', 'Switzerland', 'Austria', 'Bangladesh', 'Georgia',
#        'Guatemala', 'Jamaica', 'Greece', 'Paraguay', 'Somalia', 'Croatia'],
#       dtype=object)

# %%
# Classify International Movies 
# might need to be done by merging country_df with movie_netflix_df and then grouping US films...

# %%
# next steps: - JP Can do 
# filter type to just movies 
# remove description column
# rename listed_in to 'Netflix Genre': extract first listed_in value as Netflix Genre
# could filter out international movies, country to United States

# %%
# split neftlix_genre
# Define 1st value in listed_in column as main country the movie was produced in
genre_df = movie_netflix_df

# split genre column
split_genre_df = genre_df['netflix_genre'].str.split(',', 1, expand=True)

# Rename columns
renamed_genre_df = split_genre_df.rename(columns={0:"primary_genre",1:"other_genres"})

# drop column
drop_netflix_genre_df = renamed_genre_df.drop('other_genres', axis=1)

# Rename columns
netflix_genre_df = drop_netflix_genre_df.rename(columns={"primary_genre":"listed_in_netflix"})
netflix_genre_df.head()
# Out:
#     listed_in_netflix
# 1              Dramas
# 2       Horror Movies
# 3  Action & Adventure
# 4              Dramas
# 6       Horror Movies

# %%
#Metascore Data

CSV_2 = "Resources/metacritic_movies.csv"
metascore_df = pd.read_csv(CSV_2)
metascore_df.head()
# Out:
#            movie_title release_date                         genre  meta_mixed  \
# 0  Anatomy of a Murder     1-Jul-59  Drama,Mystery,Thriller,Crime           0
# 1     Bringing Up Baby    18-Feb-38         Comedy,Romance,Family           0
# 2           After Life    12-May-99                 Drama,Fantasy           0
# 3              Gavagai     3-Aug-18                         Drama           1
# 4          The Hustler    25-Sep-61                   Drama,Sport           1
#
#    meta_negative  meta_positive  metascore user_mixed user_negative  \
# 0              0             15         95          0             0
# 1              1             16         91          1             0
# 2              0             19         91          0             2
# 3              0              6         91          0             1
# 4              0             17         90          0             0
#
#   user_positive userscore
# 0             3       tbd
# 1             2       tbd
# 2             1       tbd
# 3             2       tbd
# 4             3       tbd

# %%
#List total columns & identify columns for revised dataframe
for col in metascore_df.columns: 
    print(col)
# Out:
# movie_title
# release_date
# genre
# meta_mixed
# meta_negative
# meta_positive
# metascore
# user_mixed
# user_negative
# user_positive
# userscore

# %%
# movie_title
# genre
# metascore

revised_metascore_df = metascore_df[["movie_title","genre","metascore"]]
revised_metascore_df.head()
# Out:
#            movie_title                         genre  metascore
# 0  Anatomy of a Murder  Drama,Mystery,Thriller,Crime         95
# 1     Bringing Up Baby         Comedy,Romance,Family         91
# 2           After Life                 Drama,Fantasy         91
# 3              Gavagai                         Drama         91
# 4          The Hustler                   Drama,Sport         90

# %%
# Rename columns
renamed_metascore_df = revised_metascore_df.rename(columns={"genre": "metacritic_genre"})
renamed_metascore_df.head()
# Out:
#            movie_title              metacritic_genre  metascore
# 0  Anatomy of a Murder  Drama,Mystery,Thriller,Crime         95
# 1     Bringing Up Baby         Comedy,Romance,Family         91
# 2           After Life                 Drama,Fantasy         91
# 3              Gavagai                         Drama         91
# 4          The Hustler                   Drama,Sport         90

# %%
# split metacritic_genre
# Define 1st value in listed_in column as main country the movie was produced in
metagenre_df = renamed_metascore_df

# split genre column
split_metagenre_df = renamed_metascore_df['metacritic_genre'].str.split(',', 1, expand=True)

# Rename columns
renamed_metagenre_df = split_metagenre_df.rename(columns={0:"primary_genre",1:"other_genres"})

# drop column
drop_genre_df = renamed_metagenre_df.drop('other_genres', axis=1)

# Rename column
metacritic_genre_df = drop_genre_df.rename(columns={"primary_genre":"metacritic_genre"})
metacritic_genre_df.head()
# Out:
#   metacritic_genre
# 0            Drama
# 1           Comedy
# 2            Drama
# 3            Drama
# 4            Drama

# %%
# merged_metacritic_df = pd.merge(revised_metascore_df, metacritic_genre_df, on="metacritic_genre")
# merged_metacritic_df.head()

# %%
# Transform Each DataFrame
